# %%
import sys
sys.path
# Out:
# ['C:\\Users\\vhphan\\PycharmProjects\\myOpenSea\\sandbox',
#  'C:\\Users\\vhphan\\AppData\\Local\\Programs\\Python\\Python38\\python38.zip',
#  'C:\\Users\\vhphan\\AppData\\Local\\Programs\\Python\\Python38\\DLLs',
#  'C:\\Users\\vhphan\\AppData\\Local\\Programs\\Python\\Python38\\lib',
#  'C:\\Users\\vhphan\\AppData\\Local\\Programs\\Python\\Python38',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv',
#  '',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv\\lib\\site-packages',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv\\lib\\site-packages\\win32',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv\\lib\\site-packages\\win32\\lib',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv\\lib\\site-packages\\Pythonwin',
#  'c:\\users\\vhphan\\pycharmprojects\\myopensea\\venv\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\vhphan\\.ipython']

# %%
import requests

# %%
base_url = 'https://api.opensea.io/api/v1'

# %%
collections_url = f'{base_url}/collections?offset=0&limit=3'

# %%
r = requests.get(collections_url)
col_info = r.json()

# %%
col_info
# Out:
# {'collections': [{'primary_asset_contracts': [],
#    'traits': {},
#    'stats': {'one_day_volume': 0.0,
#     'one_day_change': 0.0,
#     'one_day_sales': 0.0,
#     'one_day_average_price': 0.0,
#     'seven_day_volume': 0.0,
#     'seven_day_change': 0.0,
#     'seven_day_sales': 0.0,
#     'seven_day_average_price': 0.0,
#     'thirty_day_volume': 0.0,
#     'thirty_day_change': 0.0,
#     'thirty_day_sales': 0.0,
#     'thirty_day_average_price': 0.0,
#     'total_volume': 0.0,
#     'total_sales': 0.0,
#     'total_supply': 0.0,
#     'count': 0.0,
#     'num_owners': 0,
#     'average_price': 0.0,
#     'num_reports': 0,
#     'market_cap': 0.0,
#     'floor_price': 0.0},
#    'banner_image_url': None,
#    'chat_url': None,
#    'created_date': '2021-10-13T08:31:24.953187',
#    'default_to_fiat': False,
#    'description': '',
#    'dev_buyer_fee_basis_points': '0',
#    'dev_seller_fee_basis_points': '0',
#    'discord_url': None,
# ...

# %%
url = 'https://api.opensea.io/api/v1/assets?order_by=sale_price&order_direction=desc&offset=0&limit=20&collection=the-wanderers'

# %%
requests.get(url).json()
# Out:
# {'assets': [{'id': 37251700,
#    'token_id': '5224',
#    'num_sales': 2,
#    'background_color': None,
#    'image_url': 'https://storage.opensea.io/files/3cae77eb9a8951d3777174bb97a354bf.mp4',
#    'image_preview_url': 'https://storage.opensea.io/files/3cae77eb9a8951d3777174bb97a354bf.mp4',
#    'image_thumbnail_url': 'https://storage.opensea.io/files/3cae77eb9a8951d3777174bb97a354bf.mp4',
#    'image_original_url': 'https://ipfs.io/ipfs/QmWeXmth66wkCT5RYeBG9p1mnHgzAkTxoAtBdPy3CzE6o8/5224.mp4',
#    'animation_url': 'https://storage.opensea.io/files/3cae77eb9a8951d3777174bb97a354bf.mp4',
#    'animation_original_url': 'https://ipfs.io/ipfs/QmWeXmth66wkCT5RYeBG9p1mnHgzAkTxoAtBdPy3CzE6o8/5224.mp4',
#    'name': None,
#    'description': None,
#    'external_link': None,
#    'asset_contract': {'address': '0x8184a482a5038b124d933b779e0ea6e0fb72f54e',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-08-12T23:28:40.010736',
#     'name': 'Wanderers',
# ...
